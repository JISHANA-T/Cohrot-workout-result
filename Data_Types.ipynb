# %% [markdown]
# <a href="https://colab.research.google.com/github/JISHANA-T/Cohrot-workout-result/blob/main/Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
jish=np.array([1,2,3,4,5])

# %%
print(jish)
# Out:
# [1 2 3 4 5]

# %%
import  pandas as pd

# %%
print(jish+5)
# Out:
# [ 6  7  8  9 10]

# %%
print(jish*5)
# Out:
# [ 5 10 15 20 25]

# %%
print(jish**5)
# Out:
# [   1   32  243 1024 3125]

# %%
add=np.mean(jish)
print(add)
# Out:
# 3.0

# %%
jash=np.mean(jish)
print(jash)
# Out:
# 3.0

# %%
add=np.sum(jish)
print(add)
# Out:
# 15

# %%
import numpy as np
a=pd.dataframe({'Rank':[1,2,3,4,5], 'Name':['Asna','Jishana','Anitta','Ardra','Safa']})
a('c')==a['Rank']+a['Name']
9print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ccfab6e74c54> in <cell line: 0>()
#       1 import numpy as np
# ----> 2 a=pd.dataframe({'Rank':[1,2,3,4,5], 'Name':['Asna','Jishana','Anitta','Ardra','Safa']})
#       3 a('c')==a['Rank']+a['Name']
#       4 print(a)
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
import pandas as pd
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-3c5bb5c7-d779-4c06-a1fa-4ad37ab3d865" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c5bb5c7-d779-4c06-a1fa-4ad37ab3d865">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
file1=list(upload.keys())[0]
file1=pd.read_csv(file1)
print(file1['M1'])
# Out:
# 0      110.20
# 1      111.75
# 2      112.95
# 3      113.93
# 4      115.08
#         ...
# 131    475.70
# 132    490.90
# 133    505.20
# 134    517.20
# 135    523.40
# Name: M1, Length: 136, dtype: float64

# %%
x=file1['M1']
print(x)
y=file1['Y']
print(y)
# Out:
# 0      110.20
# 1      111.75
# 2      112.95
# 3      113.93
# 4      115.08
#         ...
# 131    475.70
# 132    490.90
# 133    505.20
# 134    517.20
# 135    523.40
# Name: M1, Length: 136, dtype: float64
# 0       267.6
# 1       277.1
# 2       294.8
# 3       306.3
# 4       320.4
#         ...
# 131    3109.6
# 132    3173.8
# 133    3267.0
# 134    3346.6
# 135    3431.7
# Name: Y, Length: 136, dtype: float64

# %%
import statsmodels.api as asna
x=asna.add_constant(x)
model=asna.OLS(y,x).fit()
print(model.summary())

print(file1.describe())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 2.752e+04
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):          5.65e-157
# Time:                        05:17:19   Log-Likelihood:                -751.25
# No. Observations:                 136   AIC:                             1507.
# Df Residuals:                     134   BIC:                             1512.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -646.4482     11.940    -54.141      0.000    -670.064    -622.833
# ...

# %% [markdown]
# ---
